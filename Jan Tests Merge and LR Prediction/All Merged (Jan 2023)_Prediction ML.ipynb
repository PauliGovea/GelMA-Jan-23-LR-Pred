# %% [markdown]
# # All Merged Graphs (Tests Dec/Jan 22-23)

# %%
import pandas as pd

from sklearn import preprocessing
import seaborn as sns
#from tabulate import tabulate

import numpy as np
import matplotlib.pyplot as plt
from math import nan, isnan

# %% [markdown]
# ## Data Import

# %% [markdown]
# ### GelMA only & SMPEG2

# %%
F1_only = pd.read_csv("F1_11_GelMA only.csv")
Strk1_only = pd.read_csv("Strk1_11_GelMA only.csv")
S1_only = pd.read_csv("S1_11_GelMA only.csv")
Strn1_only = pd.read_csv("Strn1_11_GelMA only.csv")

F1_SMPEG2 = pd.read_csv("F1_12_GelMA SMPEG2.csv")
Strk1_SMPEG2 = pd.read_csv("Strk1_12_GelMA SMPEG2.csv")
S1_SMPEG2 = pd.read_csv("S1_12_GelMA SMPEG2.csv")
Strn1_SMPEG2 = pd.read_csv("Strn1_12_GelMA SMPEG2.csv")

# %% [markdown]
# ### DHR14 & d1E2

# %%
F1_dhr14_1 = pd.read_csv("F1_11_dhr14(1).csv")
F1_dhr14_3 = pd.read_csv("F1_12_dhr14(3).csv")

F1_d1e2_1 = pd.read_csv("F1_13_d1E2(1).csv")
F1_d1e2_2 = pd.read_csv("F1_14_d1E2(2).csv")


Strk1_dhr14_1 = pd.read_csv("Strk1_11_dhr14(1).csv")
Strk1_dhr14_3 = pd.read_csv("Strk1_12_dhr14(3).csv")

Strk1_d1e2_1 = pd.read_csv("Strk1_13_d1e2(1).csv")
Strk1_d1e2_2 = pd.read_csv("Strk1_14_d1e2(2).csv")





S1_dhr14_1 = pd.read_csv("S1_11_dhr14(1).csv")
S1_dhr14_3 = pd.read_csv("S1_12_dhr14(3).csv")

S1_d1e2_1 = pd.read_csv("S1_13_d1E2(1).csv")
S1_d1e2_2 = pd.read_csv("S1_14_d1E2(2).csv")



Strn1_dhr14_1 = pd.read_csv("Strn1_11_dhr14(1).csv")
Strn1_dhr14_3 = pd.read_csv("Strn1_12_dhr14(3).csv")

Strn1_d1e2_1 = pd.read_csv("Strn1_13_d1e2(1).csv")
Strn1_d1e2_2 = pd.read_csv("Strn1_14_d1e2(2).csv")

# %% [markdown]
# ### e1 & eGFP

# %%
F1_e1_1 = pd.read_csv("F1_11_e1(1).csv")
F1_e1_2 = pd.read_csv("F1_12_e1(2).csv")
F1_e1_3 = pd.read_csv("F1_13_e1(3).csv")
F1_e1_4 = pd.read_csv("F1_14_e1(4).csv")
F1_e1_5 = pd.read_csv("F1_15_e1(5).csv")

F1_eGFP_1 = pd.read_csv("F1_16_eGFP(1).csv")
F1_eGFP_2 = pd.read_csv("F1_17_eGFP(2).csv")
F1_eGFP_3 = pd.read_csv("F1_18_eGFP(3).csv")
F1_eGFP_4 = pd.read_csv("F1_19_eGFP(4).csv")



Strk1_e1_1 = pd.read_csv("Strk1_11_e1(1).csv")
Strk1_e1_2 = pd.read_csv("Strk1_12_e1(2).csv")
Strk1_e1_3 = pd.read_csv("Strk1_13_e1(3).csv")
Strk1_e1_4 = pd.read_csv("Strk1_14_e1(4).csv")
Strk1_e1_5 = pd.read_csv("Strk1_15_e1(5).csv")

Strk1_eGFP_1 = pd.read_csv("Strk1_16_eGFP(1).csv")
Strk1_eGFP_2 = pd.read_csv("Strk1_17_eGFP(2).csv")
Strk1_eGFP_3 = pd.read_csv("Strk1_18_eGFP(3).csv")
Strk1_eGFP_4 = pd.read_csv("Strk1_19_eGFP(4).csv")





S1_e1_1 = pd.read_csv("S1_11_e1(1).csv")
S1_e1_2 = pd.read_csv("S1_12_e1(2).csv")
S1_e1_3 = pd.read_csv("S1_13_e1(3).csv")
S1_e1_4 = pd.read_csv("S1_14_e1(4).csv")
S1_e1_5 = pd.read_csv("S1_15_e1(5).csv")

S1_eGFP_1 = pd.read_csv("S1_16_eGFP(1).csv")
S1_eGFP_2 = pd.read_csv("S1_17_eGFP(2).csv")
S1_eGFP_3 = pd.read_csv("S1_18_eGFP(3).csv")
S1_eGFP_4 = pd.read_csv("S1_19_eGFP(4).csv")


Strn1_e1_1 = pd.read_csv("Strn1_11_e1(1).csv")
Strn1_e1_2 = pd.read_csv("Strn1_12_e1(2).csv")
Strn1_e1_3 = pd.read_csv("Strn1_13_e1(3).csv")
Strn1_e1_4 = pd.read_csv("Strn1_14_e1(4).csv")
Strn1_e1_5 = pd.read_csv("Strn1_15_e1(5).csv")

Strn1_eGFP_1 = pd.read_csv("Strn1_16_eGFP(1).csv")
Strn1_eGFP_2 = pd.read_csv("Strn1_17_eGFP(2).csv")
Strn1_eGFP_3 = pd.read_csv("Strn1_18_eGFP(3).csv")
Strn1_eGFP_4 = pd.read_csv("Strn1_19_eGFP(4).csv")

# %% [markdown]
# ### des04c1 & c2

# %%
F1_des04c1_1 = pd.read_csv("F1_11_des04c1(1).csv")

F1_des04c2_1 = pd.read_csv("F1_12_des04c2(1).csv")
F1_des04c2_2 = pd.read_csv("F1_13_des04c2(2).csv")


Strk1_des04c1_1 = pd.read_csv("Strk1_11_des04c1(1).csv")

Strk1_des04c2_1 = pd.read_csv("Strk1_12_des04c2(1).csv")
Strk1_des04c2_2 = pd.read_csv("Strk1_13_des04c2(2).csv")



S1_des04c1_1 = pd.read_csv("S1_11_des04c1(1).csv")

S1_des04c2_1 = pd.read_csv("S1_12_des04c2(1).csv")
S1_des04c2_2 = pd.read_csv("S1_12_des04c2(2).csv")


Strn1_des04c1_1 = pd.read_csv("Strn1_11_des04c1(1).csv")

Strn1_des04c2_1 = pd.read_csv("Strn1_12_des04c2(1).csv")
Strn1_des04c2_2 = pd.read_csv("Strn1_12_des04c2(2).csv")

# %%
F1_e1_1, F1_e1_2
# Out:
# (       Unnamed: 0  Mean Force
#  0               0    0.248305
#  1               1    0.247780
#  2               2    0.247002
#  3               3    0.246557
#  4               4    0.246763
#  ...           ...         ...
#  11413       11413    7.130893
#  11414       11414    7.131960
#  11415       11415    7.132815
#  11416       11416    7.133531
#  11417       11417    7.134309
#
#  [11418 rows x 2 columns],
#         Unnamed: 0  Mean Force
#  0               0    0.247590
#  1               1    0.247447
#  2               2    0.247463
#  3               3    0.247924
#  4               4    0.248257
#  ...           ...         ...
#  13727       13727   11.291950
#  13728       13728   11.287244
#  13729       13729   11.284066
#  13730       13730   11.283192
#  13731       13731   11.284130
#
#  [13732 rows x 2 columns])

# %%
F1_only
# Out:
#        Unnamed: 0  Mean Force
# 0               0    0.246636
# 1               1    0.247081
# 2               2    0.247129
# 3               3    0.247033
# 4               4    0.246986
# ...           ...         ...
# 12257       12257   11.079153
# 12258       12258   11.083158
# 12259       12259   11.086719
# 12260       12260   11.088943
# 12261       12261   11.090041
#
# [12262 rows x 2 columns]

# %% [markdown]
# # Merge Data for LinearRegression

# %% [markdown]
# ## Prediction for Force

# %% [markdown]
# ### Data cleaning FS

# %%
F1_only, F1_SMPEG2, F1_dhr14_1, F1_dhr14_3, F1_d1e2_1, F1_d1e2_2, F1_des04c1_1, F1_des04c2_1, F1_des04c2_2, F1_e1_1, F1_e1_2, F1_e1_3, F1_e1_4, F1_e1_5, F1_eGFP_1, F1_eGFP_2, F1_eGFP_3, F1_eGFP_4
Strk1_only, Strk1_SMPEG2, Strk1_dhr14_1, Strk1_dhr14_3, Strk1_d1e2_1, Strk1_d1e2_2, Strk1_des04c1_1, Strk1_des04c2_1, Strk1_des04c2_2, Strk1_e1_1, Strk1_e1_2, Strk1_e1_3, Strk1_e1_4, Strk1_e1_5, Strk1_eGFP_1, Strk1_eGFP_2, Strk1_eGFP_3, Strk1_eGFP_4

#Experiments No.
#(0) GelMA only
#(1) Normal: Photocrosslink + SMPEG2
#(2) No SMPEG2: Only Photocrosslinking
#(3) Protein BEFORE Photocrosslinking
#(4) Molarity x2
#(5) Molarity x3

#Only: Gelma Only (no protein)
#SMPEG2: Gelma only with SMPEG2 (no protein)
#DHR14_#: Gelma with DHR14 (2 cys) normal_ #no. of experiment
#d1e2_#: Gelma with DHR14 (1 cys_3 cys_TS02903885) _ #no. of experiment
#des04c1_#: Gelma with des04c1 _ #no. of experiment
#des04c2_#: Gelma with des04c2 _ #no. of experiment
#e1_#: Gelma with eGFP (3 cys_TS02903892) _ #no. of experiment
#eGFP_#: Gelma with eGFP (2 cys) normal_ #no. of experiment

F1_only
# Out:
#        Unnamed: 0  Mean Force
# 0               0    0.246636
# 1               1    0.247081
# 2               2    0.247129
# 3               3    0.247033
# 4               4    0.246986
# ...           ...         ...
# 12257       12257   11.079153
# 12258       12258   11.083158
# 12259       12259   11.086719
# 12260       12260   11.088943
# 12261       12261   11.090041
#
# [12262 rows x 2 columns]

# %%
#F1_only, F1_SMPEG2, F1_dhr14_1, F1_dhr14_3, F1_d1e2_1, F1_d1e2_2, F1_des04c1_1, F1_des04c2_1, F1_des04c2_2, F1_e1_1, F1_e1_2, F1_e1_3, F1_e1_4, F1_e1_5, F1_eGFP_1, F1_eGFP_2, F1_eGFP_3, F1_eGFP_4
#Strk1_only, Strk1_SMPEG2, Strk1_dhr14_1, Strk1_dhr14_3, Strk1_d1e2_1, Strk1_d1e2_2, Strk1_des04c1_1, Strk1_des04c2_1, Strk1_des04c2_2, Strk1_e1_1, Strk1_e1_2, Strk1_e1_3, Strk1_e1_4, Strk1_e1_5, Strk1_eGFP_1, Strk1_eGFP_2, Strk1_eGFP_3, Strk1_eGFP_4


F1_only["Stroke (mm)"] = Strk1_only["Stroke (mm)"]
F1_only["Protein"] = "0" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_only["Volume Gel (ml)"] = "2"
F1_only["Volume protein (ul)"] = "0"
F1_only["Nanomoles per sample (1nmole)"] = "0"
F1_only["I2959 (mg)"] = "15"
F1_only["SMPEG2 (uL)"] = "0"
F1_only["Prot. size (kDa)"] = "0"
F1_only["No. Experiment"] = "0"

#F1_only_2 = F1_only.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_only_2 = F1_only.drop(["Unnamed: 0"], axis = "columns")
F1_only_2


F1_SMPEG2["Stroke (mm)"] = Strk1_SMPEG2["Stroke (mm)"]
F1_SMPEG2["Protein"] = "1" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_SMPEG2["Volume Gel (ml)"] = "2"
F1_SMPEG2["Volume protein (ul)"] = "0"
F1_SMPEG2["Nanomoles per sample (1nmole)"] = "0"
F1_SMPEG2["I2959 (mg)"] = "15"
F1_SMPEG2["SMPEG2 (uL)"] = "7.2"
F1_SMPEG2["Prot. size (kDa)"] = "0"
F1_SMPEG2["No. Experiment"] = "1"

#F1_SMPEG2_2 = F1_SMPEG2.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_SMPEG2_2 = F1_SMPEG2.drop(["Unnamed: 0"], axis = "columns")
F1_SMPEG2_2


F1_dhr14_1["Stroke (mm)"] = Strk1_dhr14_1["Stroke (mm)"]
F1_dhr14_1["Protein"] = "2" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_dhr14_1["Volume Gel (ml)"] = "2"
F1_dhr14_1["Volume protein (ul)"] = "6"
F1_dhr14_1["Nanomoles per sample (1nmole)"] = "0.006"
F1_dhr14_1["I2959 (mg)"] = "15"
F1_dhr14_1["SMPEG2 (uL)"] = "7.2"
F1_dhr14_1["Prot. size (kDa)"] = "19"
F1_dhr14_1["No. Experiment"] = "1"

#F1_DHR14_1 = F1_dhr14_1.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_DHR14_1 = F1_dhr14_1.drop(["Unnamed: 0"], axis = "columns")
F1_DHR14_1


F1_dhr14_3["Stroke (mm)"] = Strk1_dhr14_3["Stroke (mm)"]
F1_dhr14_3["Protein"] = "2" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_dhr14_3["Volume Gel (ml)"] = "2"
F1_dhr14_3["Volume protein (ul)"] = "6"
F1_dhr14_3["Nanomoles per sample (1nmole)"] = "0.006"
F1_dhr14_3["I2959 (mg)"] = "15"
F1_dhr14_3["SMPEG2 (uL)"] = "7.2"
F1_dhr14_3["Prot. size (kDa)"] = "19"
F1_dhr14_3["No. Experiment"] = "3"

#F1_DHR14_3 = F1_dhr14_3.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_DHR14_3 = F1_dhr14_3.drop(["Unnamed: 0"], axis = "columns")
F1_DHR14_3



F1_d1e2_1["Stroke (mm)"] = Strk1_d1e2_1["Stroke (mm)"]
F1_d1e2_1["Protein"] = "3" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_d1e2_1["Volume Gel (ml)"] = "2"
F1_d1e2_1["Volume protein (ul)"] = "9"
F1_d1e2_1["Nanomoles per sample (1nmole)"] = "0.009"
F1_d1e2_1["I2959 (mg)"] = "15"
F1_d1e2_1["SMPEG2 (uL)"] = "7.2"
F1_d1e2_1["Prot. size (kDa)"] = "17"
F1_d1e2_1["No. Experiment"] = "1"

#F1_D1E2_1 = F1_d1e2_1.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_D1E2_1 = F1_d1e2_1.drop(["Unnamed: 0"], axis = "columns")
F1_D1E2_1


F1_d1e2_2["Stroke (mm)"] = Strk1_d1e2_2["Stroke (mm)"]
F1_d1e2_2["Protein"] = "3" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_d1e2_2["Volume Gel (ml)"] = "2"
F1_d1e2_2["Volume protein (ul)"] = "9"
F1_d1e2_2["Nanomoles per sample (1nmole)"] = "0.009"
F1_d1e2_2["I2959 (mg)"] = "15"
F1_d1e2_2["SMPEG2 (uL)"] = "7.2"
F1_d1e2_2["Prot. size (kDa)"] = "17"
F1_d1e2_2["No. Experiment"] = "2"

#F1_D1E2_2 = F1_d1e2_2.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_D1E2_2 = F1_d1e2_2.drop(["Unnamed: 0"], axis = "columns")
F1_D1E2_2


F1_des04c1_1["Stroke (mm)"] = Strk1_des04c1_1["Stroke (mm)"]
F1_des04c1_1["Protein"] = "4" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_des04c1_1["Volume Gel (ml)"] = "2"
F1_des04c1_1["Volume protein (ul)"] = "111"
F1_des04c1_1["Nanomoles per sample (1nmole)"] = "0.111"  #4nm for tetramers
F1_des04c1_1["I2959 (mg)"] = "15"
F1_des04c1_1["SMPEG2 (uL)"] = "7.2"
F1_des04c1_1["Prot. size (kDa)"] = "85" #85kDa *4
F1_des04c1_1["No. Experiment"] = "1"

#F1_DES1_1 = F1_des04c1_1.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_DES1_1 = F1_des04c1_1.drop(["Unnamed: 0"], axis = "columns")
F1_DES1_1



F1_des04c2_1["Stroke (mm)"] = Strk1_des04c2_1["Stroke (mm)"]
F1_des04c2_1["Protein"] = "4" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_des04c2_1["Volume Gel (ml)"] = "2"
F1_des04c2_1["Volume protein (ul)"] = "111"
F1_des04c2_1["Nanomoles per sample (1nmole)"] = "0.111" #4nm for tetramers
F1_des04c2_1["I2959 (mg)"] = "15"
F1_des04c2_1["SMPEG2 (uL)"] = "7.2"
F1_des04c2_1["Prot. size (kDa)"] = "85" #85kDa *4
F1_des04c2_1["No. Experiment"] = "1"

#F1_DES2_1 = F1_des04c2_1.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_DES2_1 = F1_des04c2_1.drop(["Unnamed: 0"], axis = "columns")
F1_DES2_1



F1_des04c2_2["Stroke (mm)"] = Strk1_des04c2_2["Stroke (mm)"]
F1_des04c2_2["Protein"] = "4" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_des04c2_2["Volume Gel (ml)"] = "2"
F1_des04c2_2["Volume protein (ul)"] = "111"
F1_des04c2_2["Nanomoles per sample (1nmole)"] = "0.111" #4nm for tetramers
F1_des04c2_2["I2959 (mg)"] = "15"
F1_des04c2_2["SMPEG2 (uL)"] = "7.2"
F1_des04c2_2["Prot. size (kDa)"] = "85" #85kDa *4 = 340
F1_des04c2_2["No. Experiment"] = "2"

#F1_DES2_2 = F1_des04c2_2.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_DES2_2 = F1_des04c2_2.drop(["Unnamed: 0"], axis = "columns")
F1_DES2_2


F1_e1_1["Stroke (mm)"] = Strk1_e1_1["Stroke (mm)"]
F1_e1_1["Protein"] = "7" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_e1_1["Volume Gel (ml)"] = "2"
F1_e1_1["Volume protein (ul)"] = "21"
F1_e1_1["Nanomoles per sample (1nmole)"] = "0.021"
F1_e1_1["I2959 (mg)"] = "15"
F1_e1_1["SMPEG2 (uL)"] = "7.2"
F1_e1_1["Prot. size (kDa)"] = "35"
F1_e1_1["No. Experiment"] = "1"

#F1_E1_1 = F1_e1_1.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_E1_1 = F1_e1_1.drop(["Unnamed: 0"], axis = "columns")
F1_E1_1


F1_e1_2["Stroke (mm)"] = Strk1_e1_2["Stroke (mm)"]
F1_e1_2["Protein"] = "7" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_e1_2["Volume Gel (ml)"] = "2"
F1_e1_2["Volume protein (ul)"] = "21"
F1_e1_2["Nanomoles per sample (1nmole)"] = "0.021"
F1_e1_2["I2959 (mg)"] = "15"
F1_e1_2["SMPEG2 (uL)"] = "7.2"
F1_e1_2["Prot. size (kDa)"] = "35"
F1_e1_2["No. Experiment"] = "2"

#F1_E1_2 = F1_e1_2.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_E1_2 = F1_e1_2.drop(["Unnamed: 0"], axis = "columns")
F1_E1_2


F1_e1_3["Stroke (mm)"] = Strk1_e1_3["Stroke (mm)"]
F1_e1_3["Protein"] = "7" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_e1_3["Volume Gel (ml)"] = "2"
F1_e1_3["Volume protein (ul)"] = "21"
F1_e1_3["Nanomoles per sample (1nmole)"] = "0.021"
F1_e1_3["I2959 (mg)"] = "15"
F1_e1_3["SMPEG2 (uL)"] = "7.2"
F1_e1_3["Prot. size (kDa)"] = "35"
F1_e1_3["No. Experiment"] = "3"

#F1_E1_3 = F1_e1_3.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_E1_3 = F1_e1_3.drop(["Unnamed: 0"], axis = "columns")
F1_E1_3



F1_e1_4["Stroke (mm)"] = Strk1_e1_4["Stroke (mm)"]
F1_e1_4["Protein"] = "7" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_e1_4["Volume Gel (ml)"] = "2"
F1_e1_4["Volume protein (ul)"] = "21"
F1_e1_4["Nanomoles per sample (1nmole)"] = "0.021"
F1_e1_4["I2959 (mg)"] = "15"
F1_e1_4["SMPEG2 (uL)"] = "7.2"
F1_e1_4["Prot. size (kDa)"] = "35"
F1_e1_4["No. Experiment"] = "4"

#F1_E1_4 = F1_e1_4.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_E1_4 = F1_e1_4.drop(["Unnamed: 0"], axis = "columns")
F1_E1_4



F1_e1_5["Stroke (mm)"] = Strk1_e1_5["Stroke (mm)"]
F1_e1_5["Protein"] = "7" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_e1_5["Volume Gel (ml)"] = "2"
F1_e1_5["Volume protein (ul)"] = "21"
F1_e1_5["Nanomoles per sample (1nmole)"] = "0.021"
F1_e1_5["I2959 (mg)"] = "15"
F1_e1_5["SMPEG2 (uL)"] = "7.2"
F1_e1_5["Prot. size (kDa)"] = "35"
F1_e1_5["No. Experiment"] = "5"

#F1_E1_5 = F1_e1_5.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_E1_5 = F1_e1_5.drop(["Unnamed: 0"], axis = "columns")
F1_E1_5

F1_eGFP_1["Stroke (mm)"] = Strk1_eGFP_1["Stroke (mm)"]
F1_eGFP_1["Protein"] = "6" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_eGFP_1["Volume Gel (ml)"] = "2"
F1_eGFP_1["Volume protein (ul)"] = "41"
F1_eGFP_1["Nanomoles per sample (1nmole)"] = "0.041"
F1_eGFP_1["I2959 (mg)"] = "15"
F1_eGFP_1["SMPEG2 (uL)"] = "7.2"
F1_eGFP_1["Prot. size (kDa)"] = "30"
F1_eGFP_1["No. Experiment"] = "1"

#F1_EGFP_1 = F1_eGFP_1.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_EGFP_1 = F1_eGFP_1.drop(["Unnamed: 0"], axis = "columns")
F1_EGFP_1


F1_eGFP_2["Stroke (mm)"] = Strk1_eGFP_2["Stroke (mm)"]
F1_eGFP_2["Protein"] = "6" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_eGFP_2["Volume Gel (ml)"] = "2"
F1_eGFP_2["Volume protein (ul)"] = "41"
F1_eGFP_2["Nanomoles per sample (1nmole)"] = "0.041"
F1_eGFP_2["I2959 (mg)"] = "15"
F1_eGFP_2["SMPEG2 (uL)"] = "7.2"
F1_eGFP_2["Prot. size (kDa)"] = "30"
F1_eGFP_2["No. Experiment"] = "2"

#F1_EGFP_2 = F1_eGFP_2.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_EGFP_2 = F1_eGFP_2.drop(["Unnamed: 0"], axis = "columns")
F1_EGFP_2

F1_eGFP_3["Stroke (mm)"] = Strk1_eGFP_3["Stroke (mm)"]
F1_eGFP_3["Protein"] = "6" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_eGFP_3["Volume Gel (ml)"] = "2"
F1_eGFP_3["Volume protein (ul)"] = "41"
F1_eGFP_3["Nanomoles per sample (1nmole)"] = "0.041"
F1_eGFP_3["I2959 (mg)"] = "15"
F1_eGFP_3["SMPEG2 (uL)"] = "7.2"
F1_eGFP_3["Prot. size (kDa)"] = "30"
F1_eGFP_3["No. Experiment"] = "3"

#F1_EGFP_3 = F1_eGFP_3.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_EGFP_3 = F1_eGFP_3.drop(["Unnamed: 0"], axis = "columns")
F1_EGFP_3


F1_eGFP_4["Stroke (mm)"] = Strk1_eGFP_4["Stroke (mm)"]
F1_eGFP_4["Protein"] = "6" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
F1_eGFP_4["Volume Gel (ml)"] = "2"
F1_eGFP_4["Volume protein (ul)"] = "41"
F1_eGFP_4["Nanomoles per sample (1nmole)"] = "0.041"
F1_eGFP_4["I2959 (mg)"] = "15"
F1_eGFP_4["SMPEG2 (uL)"] = "7.2"
F1_eGFP_4["Prot. size (kDa)"] = "30"
F1_eGFP_4["No. Experiment"] = "4"

#F1_EGFP_4 = F1_eGFP_4.drop(["Std", "Error1", "Error2"], axis = "columns")
F1_EGFP_4 = F1_eGFP_4.drop(["Unnamed: 0"], axis = "columns")
F1_EGFP_4



F1_ALL = F1_only_2.append([F1_SMPEG2_2, F1_DHR14_1, F1_DHR14_3, F1_D1E2_1, F1_D1E2_2, F1_DES1_1, F1_DES2_1, F1_DES2_2, F1_E1_1, F1_E1_2, F1_E1_3, F1_E1_4, F1_E1_5, F1_EGFP_1, F1_EGFP_2, F1_EGFP_3, F1_EGFP_4])

F1_ALL #364994 rows × 11 columns
# Out:
# /var/folders/97/y1n8_jns6rl_dk0yr67c2ws00000gn/T/ipykernel_77489/1442747036.py:279: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   F1_ALL = F1_only_2.append([F1_SMPEG2_2, F1_DHR14_1, F1_DHR14_3, F1_D1E2_1, F1_D1E2_2, F1_DES1_1, F1_DES2_1, F1_DES2_2, F1_E1_1, F1_E1_2, F1_E1_3, F1_E1_4, F1_E1_5, F1_EGFP_1, F1_EGFP_2, F1_EGFP_3, F1_EGFP_4])
#        Mean Force  Stroke (mm) Protein Volume Gel (ml) Volume protein (ul)  \
# 0        0.246636     0.000000       0               2                   0
# 1        0.247081     0.000020       0               2                   0
# 2        0.247129     0.000027       0               2                   0
# 3        0.247033     0.000033       0               2                   0
# 4        0.246986     0.000067       0               2                   0
# ...           ...          ...     ...             ...                 ...
# ...

# %% [markdown]
# ### Linear Regression ML

# %%
from sklearn.linear_model import LinearRegression

# %%
features = F1_ALL.drop(["Mean Force"], axis="columns")
target = F1_ALL["Mean Force"]

features
# Out:
#        Stroke (mm) Protein Volume Gel (ml) Volume protein (ul)  \
# 0         0.000000       0               2                   0
# 1         0.000020       0               2                   0
# 2         0.000027       0               2                   0
# 3         0.000033       0               2                   0
# 4         0.000067       0               2                   0
# ...            ...     ...             ...                 ...
# 22934     2.293353       6               2                  41
# 22935     2.293447       6               2                  41
# 22936     2.293560       6               2                  41
# 22937     2.293673       6               2                  41
# 22938     2.293760       6               2                  41
#
#       Nanomoles per sample (1nmole) I2959 (mg) SMPEG2 (uL) Prot. size (kDa)  \
# 0                                 0         15           0                0
# ...

# %%
model = LinearRegression()

# %%
model.fit(features, target)
# Out:
# LinearRegression()

# %%
model.score(features, target) #the inputs (data) we have can help us predict around 90% of change in the force of the hydrogel
# Out:
# 0.9049173254812707

# %%
hydrogel_FS = pd.DataFrame({
             'Stroke (mm)': [1.8],
             'Protein': [4], #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
             'Volume Gel (ml)': [2],
             'Volume protein (ul)': [60],
             'Nanomoles per sample (1nmole)': [0.06],
             'I2959 (mg)': [15],
             'SMPEG2 (uL)': [7.2],
             'Prot. size (kDa)': [85], #In accordance to protein above: DHR14 19kDa, des04c 85kDa per chain, eGFP 35kDa
             'No. Experiment': [4] 
         })

#Experiments No.
#(0) GelMA only
#(1) Normal: Photocrosslink + SMPEG2
#(2) No SMPEG2: Only Photocrosslinking
#(3) Protein BEFORE Photocrosslinking
#(4) Molarity x2
#(5) Molarity x3

# %% [markdown]
# #### Prediction

# %%
hydrogel_predict = model.predict(hydrogel_FS)

print(f" Your predicted Force of the hyrogel is: {hydrogel_predict}[N]")
# Out:
#  Your predicted Force of the hyrogel is: [13.00332774][N]

# %% [markdown]
# ## Prediction for Stress

# %% [markdown]
# ### Data Cleaning SS

# %%
S1_only, S1_SMPEG2, S1_dhr14_1, S1_dhr14_3, S1_d1e2_1, S1_d1e2_2, S1_des04c1_1, S1_des04c2_1, S1_des04c2_2, S1_e1_1, S1_e1_2, S1_e1_3, S1_e1_4, S1_e1_5, S1_eGFP_1, S1_eGFP_2, S1_eGFP_3, S1_eGFP_4
Strn1_only, Strn1_SMPEG2, Strn1_dhr14_1, Strn1_dhr14_3, Strn1_d1e2_1, Strn1_d1e2_2, Strn1_des04c1_1, Strn1_des04c2_1, Strn1_des04c2_2, Strn1_e1_1, Strn1_e1_2, Strn1_e1_3, Strn1_e1_4, Strn1_e1_5, Strn1_eGFP_1, Strn1_eGFP_2, Strn1_eGFP_3, Strn1_eGFP_4

#Experiments No.
#(1) Normal: Photocrosslink + SMPEG2
#(2) No SMPEG2: Only Photocrosslinking
#(3) Protein BEFORE Photocrosslinking
#(4) Molarity x2
#(5) Molarity x3

#Only: Gelma Only (no protein)
#SMPEG2: Gelma only with SMPEG2 (no protein)
#DHR14_#: Gelma with DHR14 (2 cys) normal_ #no. of experiment
#d1e2_#: Gelma with DHR14 (1 cys_3 cys_TS02903885) _ #no. of experiment
#des04c1_#: Gelma with des04c1 _ #no. of experiment
#des04c2_#: Gelma with des04c2 _ #no. of experiment
#e1_#: Gelma with eGFP (3 cys_TS02903892) _ #no. of experiment
#eGFP_#: Gelma with eGFP (2 cys) normal_ #no. of experiment
# Out:
# (       Unnamed: 0    Strain
#  0               0  0.000000
#  1               1  0.000008
#  2               2  0.000010
#  3               3  0.000013
#  4               4  0.000025
#  ...           ...       ...
#  13413       13413  0.503495
#  13414       13414  0.503527
#  13415       13415  0.503562
#  13416       13416  0.503600
#  13417       13417  0.503633
#
#  [13418 rows x 2 columns],
#         Unnamed: 0    Strain
#  0               0  0.000000
#  1               1  0.000000
#  2               2  0.000012
#  3               3  0.000014
#  4               4  0.000025
#  ...           ...       ...
#  12204       12204  0.519316
#  12205       12205  0.519359
#  12206       12206  0.519398
#  12207       12207  0.519444
#  12208       12208  0.519485
#
#  [12209 rows x 2 columns],
#         Unnamed: 0    Strain
#  0               0  0.000000
#  1               1  0.000001
#  2               2  0.000004
#  3               3  0.000004
#  4               4  0.000009
# ...

# %%
Strn1_only
# Out:
#        Unnamed: 0    Strain
# 0               0  0.000000
# 1               1  0.000008
# 2               2  0.000010
# 3               3  0.000013
# 4               4  0.000025
# ...           ...       ...
# 13413       13413  0.503495
# 13414       13414  0.503527
# 13415       13415  0.503562
# 13416       13416  0.503600
# 13417       13417  0.503633
#
# [13418 rows x 2 columns]

# %%
S1_only["Strain"] = Strn1_only["Strain"]
S1_only["Protein"] = "0" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_only["Volume Gel (ml)"] = "2"
S1_only["Volume protein (ul)"] = "0"
S1_only["Nanomoles per sample (1nmole)"] = "0"
S1_only["I2959 (mg)"] = "15"
S1_only["SMPEG2 (uL)"] = "0"
S1_only["Prot. size (kDa)"] = "0"
S1_only["No. Experiment"] = "0"

#S1_only_2 = S1_only.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_only_2 = S1_only.drop(["Unnamed: 0"], axis = "columns")
S1_only_2


S1_SMPEG2["Strain"] = Strn1_SMPEG2["Strain"]
S1_SMPEG2["Protein"] = "1" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_SMPEG2["Volume Gel (ml)"] = "2"
S1_SMPEG2["Volume protein (ul)"] = "0"
S1_SMPEG2["Nanomoles per sample (1nmole)"] = "0"
S1_SMPEG2["I2959 (mg)"] = "15"
S1_SMPEG2["SMPEG2 (uL)"] = "7.2"
S1_SMPEG2["Prot. size (kDa)"] = "0"
S1_SMPEG2["No. Experiment"] = "1"

#S1_SMPEG2_2 = S1_SMPEG2.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_SMPEG2_2 = S1_SMPEG2.drop(["Unnamed: 0"], axis = "columns")
S1_SMPEG2_2


S1_dhr14_1["Strain"] = Strn1_dhr14_1["Strain"]
S1_dhr14_1["Protein"] = "2" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_dhr14_1["Volume Gel (ml)"] = "2"
S1_dhr14_1["Volume protein (ul)"] = "6"
S1_dhr14_1["Nanomoles per sample (1nmole)"] = "0.006"
S1_dhr14_1["I2959 (mg)"] = "15"
S1_dhr14_1["SMPEG2 (uL)"] = "7.2"
S1_dhr14_1["Prot. size (kDa)"] = "19"
S1_dhr14_1["No. Experiment"] = "1"

#S1_DHR14_1 = S1_dhr14_1.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_DHR14_1 = S1_dhr14_1.drop(["Unnamed: 0"], axis = "columns")
S1_DHR14_1


S1_dhr14_3["Strain"] = Strn1_dhr14_3["Strain"]
S1_dhr14_3["Protein"] = "2" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_dhr14_3["Volume Gel (ml)"] = "2"
S1_dhr14_3["Volume protein (ul)"] = "6"
S1_dhr14_3["Nanomoles per sample (1nmole)"] = "0.006"
S1_dhr14_3["I2959 (mg)"] = "15"
S1_dhr14_3["SMPEG2 (uL)"] = "7.2"
S1_dhr14_3["Prot. size (kDa)"] = "19"
S1_dhr14_3["No. Experiment"] = "3"

#S1_DHR14_3 = S1_dhr14_3.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_DHR14_3 = S1_dhr14_3.drop(["Unnamed: 0"], axis = "columns")
S1_DHR14_3



S1_d1e2_1["Strain"] = Strn1_d1e2_1["Strain"]
S1_d1e2_1["Protein"] = "3" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_d1e2_1["Volume Gel (ml)"] = "2"
S1_d1e2_1["Volume protein (ul)"] = "9"
S1_d1e2_1["Nanomoles per sample (1nmole)"] = "0.009"
S1_d1e2_1["I2959 (mg)"] = "15"
S1_d1e2_1["SMPEG2 (uL)"] = "7.2"
S1_d1e2_1["Prot. size (kDa)"] = "17"
S1_d1e2_1["No. Experiment"] = "1"

#S1_D1E2_1 = S1_d1e2_1.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_D1E2_1 = S1_d1e2_1.drop(["Unnamed: 0"], axis = "columns")
S1_D1E2_1


S1_d1e2_2["Strain"] = Strn1_d1e2_2["Strain"]
S1_d1e2_2["Protein"] = "3" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_d1e2_2["Volume Gel (ml)"] = "2"
S1_d1e2_2["Volume protein (ul)"] = "9"
S1_d1e2_2["Nanomoles per sample (1nmole)"] = "0.009"
S1_d1e2_2["I2959 (mg)"] = "15"
S1_d1e2_2["SMPEG2 (uL)"] = "7.2"
S1_d1e2_2["Prot. size (kDa)"] = "17"
S1_d1e2_2["No. Experiment"] = "2"

#S1_D1E2_2 = S1_d1e2_2.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_D1E2_2 = S1_d1e2_2.drop(["Unnamed: 0"], axis = "columns")
S1_D1E2_2


S1_des04c1_1["Strain"] = Strn1_des04c1_1["Strain"]
S1_des04c1_1["Protein"] = "4" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_des04c1_1["Volume Gel (ml)"] = "2"
S1_des04c1_1["Volume protein (ul)"] = "111"
S1_des04c1_1["Nanomoles per sample (1nmole)"] = "0.111"  #4nm for tetramers
S1_des04c1_1["I2959 (mg)"] = "15"
S1_des04c1_1["SMPEG2 (uL)"] = "7.2"
S1_des04c1_1["Prot. size (kDa)"] = "85" #85kDa *4
S1_des04c1_1["No. Experiment"] = "1"

#S1_DES1_1 = S1_des04c1_1.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_DES1_1 = S1_des04c1_1.drop(["Unnamed: 0"], axis = "columns")
S1_DES1_1



S1_des04c2_1["Strain"] = Strn1_des04c2_1["Strain"]
S1_des04c2_1["Protein"] = "4" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_des04c2_1["Volume Gel (ml)"] = "2"
S1_des04c2_1["Volume protein (ul)"] = "111"
S1_des04c2_1["Nanomoles per sample (1nmole)"] = "0.111" #4nm for tetramers
S1_des04c2_1["I2959 (mg)"] = "15"
S1_des04c2_1["SMPEG2 (uL)"] = "7.2"
S1_des04c2_1["Prot. size (kDa)"] = "85" #85kDa *4
S1_des04c2_1["No. Experiment"] = "1"

#S1_DES2_1 = S1_des04c2_1.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_DES2_1 = S1_des04c2_1.drop(["Unnamed: 0"], axis = "columns")
S1_DES2_1



S1_des04c2_2["Strain"] = Strn1_des04c2_2["Strain"]
S1_des04c2_2["Protein"] = "4" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_des04c2_2["Volume Gel (ml)"] = "2"
S1_des04c2_2["Volume protein (ul)"] = "111"
S1_des04c2_2["Nanomoles per sample (1nmole)"] = "0.111" #4nm for tetramers
S1_des04c2_2["I2959 (mg)"] = "15"
S1_des04c2_2["SMPEG2 (uL)"] = "7.2"
S1_des04c2_2["Prot. size (kDa)"] = "85" #85kDa *4 = 340
S1_des04c2_2["No. Experiment"] = "2"

#S1_DES2_2 = S1_des04c2_2.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_DES2_2 = S1_des04c2_2.drop(["Unnamed: 0"], axis = "columns")
S1_DES2_2


S1_e1_1["Strain"] = Strn1_e1_1["Strain"]
S1_e1_1["Protein"] = "7" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_e1_1["Volume Gel (ml)"] = "2"
S1_e1_1["Volume protein (ul)"] = "21"
S1_e1_1["Nanomoles per sample (1nmole)"] = "0.021"
S1_e1_1["I2959 (mg)"] = "15"
S1_e1_1["SMPEG2 (uL)"] = "7.2"
S1_e1_1["Prot. size (kDa)"] = "35"
S1_e1_1["No. Experiment"] = "1"

#S1_E1_1 = S1_e1_1.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_E1_1 = S1_e1_1.drop(["Unnamed: 0"], axis = "columns")
S1_E1_1


S1_e1_2["Strain"] = Strn1_e1_2["Strain"]
S1_e1_2["Protein"] = "7" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_e1_2["Volume Gel (ml)"] = "2"
S1_e1_2["Volume protein (ul)"] = "21"
S1_e1_2["Nanomoles per sample (1nmole)"] = "0.021"
S1_e1_2["I2959 (mg)"] = "15"
S1_e1_2["SMPEG2 (uL)"] = "7.2"
S1_e1_2["Prot. size (kDa)"] = "35"
S1_e1_2["No. Experiment"] = "2"

#S1_E1_2 = S1_e1_2.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_E1_2 = S1_e1_2.drop(["Unnamed: 0"], axis = "columns")
S1_E1_2


S1_e1_3["Strain"] = Strn1_e1_3["Strain"]
S1_e1_3["Protein"] = "7" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_e1_3["Volume Gel (ml)"] = "2"
S1_e1_3["Volume protein (ul)"] = "21"
S1_e1_3["Nanomoles per sample (1nmole)"] = "0.021"
S1_e1_3["I2959 (mg)"] = "15"
S1_e1_3["SMPEG2 (uL)"] = "7.2"
S1_e1_3["Prot. size (kDa)"] = "35"
S1_e1_3["No. Experiment"] = "3"

#S1_E1_3 = S1_e1_3.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_E1_3 = S1_e1_3.drop(["Unnamed: 0"], axis = "columns")
S1_E1_3



S1_e1_4["Strain"] = Strn1_e1_4["Strain"]
S1_e1_4["Protein"] = "7" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_e1_4["Volume Gel (ml)"] = "2"
S1_e1_4["Volume protein (ul)"] = "21"
S1_e1_4["Nanomoles per sample (1nmole)"] = "0.021"
S1_e1_4["I2959 (mg)"] = "15"
S1_e1_4["SMPEG2 (uL)"] = "7.2"
S1_e1_4["Prot. size (kDa)"] = "35"
S1_e1_4["No. Experiment"] = "4"

#S1_E1_4 = S1_e1_4.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_E1_4 = S1_e1_4.drop(["Unnamed: 0"], axis = "columns")
S1_E1_4



S1_e1_5["Strain"] = Strn1_e1_5["Strain"]
S1_e1_5["Protein"] = "7" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_e1_5["Volume Gel (ml)"] = "2"
S1_e1_5["Volume protein (ul)"] = "21"
S1_e1_5["Nanomoles per sample (1nmole)"] = "0.021"
S1_e1_5["I2959 (mg)"] = "15"
S1_e1_5["SMPEG2 (uL)"] = "7.2"
S1_e1_5["Prot. size (kDa)"] = "35"
S1_e1_5["No. Experiment"] = "5"

#S1_E1_5 = S1_e1_5.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_E1_5 = S1_e1_5.drop(["Unnamed: 0"], axis = "columns")
S1_E1_5



S1_eGFP_1["Strain"] = Strn1_eGFP_1["Strain"]
S1_eGFP_1["Protein"] = "6" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_eGFP_1["Volume Gel (ml)"] = "2"
S1_eGFP_1["Volume protein (ul)"] = "41"
S1_eGFP_1["Nanomoles per sample (1nmole)"] = "0.041"
S1_eGFP_1["I2959 (mg)"] = "15"
S1_eGFP_1["SMPEG2 (uL)"] = "7.2"
S1_eGFP_1["Prot. size (kDa)"] = "30"
S1_eGFP_1["No. Experiment"] = "1"

#S1_EGFP_1 = S1_eGFP_1.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_EGFP_1 = S1_eGFP_1.drop(["Unnamed: 0"], axis = "columns")
S1_EGFP_1


S1_eGFP_2["Strain"] = Strn1_eGFP_2["Strain"]
S1_eGFP_2["Protein"] = "6" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_eGFP_2["Volume Gel (ml)"] = "2"
S1_eGFP_2["Volume protein (ul)"] = "41"
S1_eGFP_2["Nanomoles per sample (1nmole)"] = "0.041"
S1_eGFP_2["I2959 (mg)"] = "15"
S1_eGFP_2["SMPEG2 (uL)"] = "7.2"
S1_eGFP_2["Prot. size (kDa)"] = "30"
S1_eGFP_2["No. Experiment"] = "2"

#S1_EGFP_2 = S1_eGFP_2.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_EGFP_2 = S1_eGFP_2.drop(["Unnamed: 0"], axis = "columns")
S1_EGFP_2




S1_eGFP_3["Strain"] = Strn1_eGFP_3["Strain"]
S1_eGFP_3["Protein"] = "6" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_eGFP_3["Volume Gel (ml)"] = "2"
S1_eGFP_3["Volume protein (ul)"] = "41"
S1_eGFP_3["Nanomoles per sample (1nmole)"] = "0.041"
S1_eGFP_3["I2959 (mg)"] = "15"
S1_eGFP_3["SMPEG2 (uL)"] = "7.2"
S1_eGFP_3["Prot. size (kDa)"] = "30"
S1_eGFP_3["No. Experiment"] = "3"

#S1_EGFP_3 = S1_eGFP_3.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_EGFP_3 = S1_eGFP_3.drop(["Unnamed: 0"], axis = "columns")
S1_EGFP_3




S1_eGFP_4["Strain"] = Strn1_eGFP_4["Strain"]
S1_eGFP_4["Protein"] = "6" #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
S1_eGFP_4["Volume Gel (ml)"] = "2"
S1_eGFP_4["Volume protein (ul)"] = "41"
S1_eGFP_4["Nanomoles per sample (1nmole)"] = "0.041"
S1_eGFP_4["I2959 (mg)"] = "15"
S1_eGFP_4["SMPEG2 (uL)"] = "7.2"
S1_eGFP_4["Prot. size (kDa)"] = "30"
S1_eGFP_4["No. Experiment"] = "4"

#S1_EGFP_4 = S1_eGFP_4.drop(["Std", "Error1", "Error2"], axis = "columns")
S1_EGFP_4 = S1_eGFP_4.drop(["Unnamed: 0"], axis = "columns")
S1_EGFP_4



S1_ALL = S1_only_2.append([S1_SMPEG2_2, S1_DHR14_1, S1_DHR14_3, S1_D1E2_1, S1_D1E2_2, S1_DES1_1, S1_DES2_1, S1_DES2_2, S1_E1_1, S1_E1_2, S1_E1_3, S1_E1_4, S1_E1_5, S1_EGFP_1, S1_EGFP_2, S1_EGFP_3, S1_EGFP_4])

S1_ALL #364994 rows × 11 columns
# Out:
# /var/folders/97/y1n8_jns6rl_dk0yr67c2ws00000gn/T/ipykernel_77489/3499870657.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S1_ALL = S1_only_2.append([S1_SMPEG2_2, S1_DHR14_1, S1_DHR14_3, S1_D1E2_1, S1_D1E2_2, S1_DES1_1, S1_DES2_1, S1_DES2_2, S1_E1_1, S1_E1_2, S1_E1_3, S1_E1_4, S1_E1_5, S1_EGFP_1, S1_EGFP_2, S1_EGFP_3, S1_EGFP_4])
#        Mean Stress    Strain Protein Volume Gel (ml) Volume protein (ul)  \
# 0         2.176159  0.000000       0               2                   0
# 1         2.180276  0.000008       0               2                   0
# 2         2.180800  0.000010       0               2                   0
# 3         2.179898  0.000013       0               2                   0
# 4         2.179386  0.000025       0               2                   0
# ...            ...       ...     ...             ...                 ...
# ...

# %% [markdown]
# ### Linear Regression ML

# %%
features_2 = S1_ALL.drop(["Mean Stress"], axis="columns")
target_2 = S1_ALL["Mean Stress"]

features_2
# Out:
#          Strain Protein Volume Gel (ml) Volume protein (ul)  \
# 0      0.000000       0               2                   0
# 1      0.000008       0               2                   0
# 2      0.000010       0               2                   0
# 3      0.000013       0               2                   0
# 4      0.000025       0               2                   0
# ...         ...     ...             ...                 ...
# 22934  0.417813       6               2                  41
# 22935  0.417830       6               2                  41
# 22936  0.417851       6               2                  41
# 22937  0.417872       6               2                  41
# 22938  0.417887       6               2                  41
#
#       Nanomoles per sample (1nmole) I2959 (mg) SMPEG2 (uL) Prot. size (kDa)  \
# 0                                 0         15           0                0
# 1                                 0         15           0                0
# ...

# %%
#model = LinearRegression()

# %%
model.fit(features_2, target_2)
# Out:
# LinearRegression()

# %%
model.score(features_2, target_2) #the inputs (data) I have can predict around 78% of change in the force of the hydrogel

# More Data, more accurate
# Out:
# 0.7882272602805522

# %%
hydrogel_SS = pd.DataFrame({
             'Strain': [0.43],
             'Protein': [3], #0: none, 1: smpeg only, 2: dhr14, 3: dhr14_1cys, 4: des04c1, 5: des04c2, 6: eGFP, 7: eGFP_3cys
             'Volume Gel (ml)': [2],
             'Volume protein (ul)': [10],
             'Nanomoles per sample (1nmole)': [1],
             'I2959 (mg)': [15],
             'SMPEG2 (uL)': [7.2],
             'Prot. size (kDa)': [85], #In accordance to protein above: DHR14 19kDa, des04c 85kDa per chain, eGFP 35kDa
             'No. Experiment': [1] 
         })

#Experiments No.
#(0) GelMA only
#(1) Normal: Photocrosslink + SMPEG2
#(2) No SMPEG2: Only Photocrosslinking
#(3) Protein BEFORE Photocrosslinking
#(4) Molarity x2
#(5) Molarity x3

# %% [markdown]
# #### Prediction

# %%
hydrogel_predict_2 = model.predict(hydrogel_SS)
print(f" Your predicted hydrogel STRESS is: {hydrogel_predict_2}[kPa]")
# Out:
#  Your predicted hydrogel STRESS is: [87.34689139][kPa]
